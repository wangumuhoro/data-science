# %%
import pandas as pd

# %%
listnew = ['Macleen', 'Wambo','Shiko','Doris']
listnew
# Out:
# ['Macleen', 'Wambo', 'Shiko', 'Doris']

# %%
series1= pd.Series(listnew)
series1
# Out:
# 0    Macleen
# 1      Wambo
# 2      Shiko
# 3      Doris
# dtype: object

# %%
df1 =pd.DataFrame(listnew)
df1
# Out:
#          0
# 0  Macleen
# 1    Wambo
# 2    Shiko
# 3    Doris

# %%
df1.dtypes
# Out:
# 0    object
# dtype: object

# %%
newList= ['Apple','Banana','Mango'] 
newList
# Out:
# ['Apple', 'Banana', 'Mango']

# %%
series1= pd.Series(newList)
series1
# Out:
# 0     Apple
# 1    Banana
# 2     Mango
# dtype: object

# %%
df1= pd.DataFrame(newList)
df1
# Out:
#         0
# 0   Apple
# 1  Banana
# 2   Mango

# %%
import pandas as pd

# %%
df = pd.read_csv("IRIS.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
df.tail(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 142           5.8          2.7           5.1          1.9  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.shape
# Out:
# (150, 5)

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.iloc[0,0]
# Out:
# 5.1

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.iloc[0:5,4]
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: species, dtype: object

# %%
df.iloc[-5:,-1]
# Out:
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, dtype: object

# %%
df.iloc[[0,5,6,7],[1,2,3]]
# Out:
#    sepal_width  petal_length  petal_width
# 0          3.5           1.4          0.2
# 5          3.9           1.7          0.4
# 6          3.4           1.4          0.3
# 7          3.4           1.5          0.2

# %%
df.loc[0,'petal_width']
# Out:
# 0.2

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df2 = pd.read_csv("IRIS.csv", index_col = 'sepal_length')

# %%
df2.head()
# Out:
#               sepal_width  petal_length  petal_width      species
# sepal_length
# 5.1                   3.5           1.4          0.2  Iris-setosa
# 4.9                   3.0           1.4          0.2  Iris-setosa
# 4.7                   3.2           1.3          0.2  Iris-setosa
# 4.6                   3.1           1.5          0.2  Iris-setosa
# 5.0                   3.6           1.4          0.2  Iris-setosa

# %%
df.loc[2]
# Out:
# sepal_length            4.7
# sepal_width             3.2
# petal_length            1.3
# petal_width             0.2
# species         Iris-setosa
# Name: 2, dtype: object

# %%
df.loc[0:5,"species"]
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# 5    Iris-setosa
# Name: species, dtype: object

# %%
df.species
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object

# %%
df.petal_length
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal_length, Length: 150, dtype: float64

# %%
df['petal_length']
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal_length, Length: 150, dtype: float64

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df[['sepal_length','sepal_width','petal_length']]
# Out:
#      sepal_length  sepal_width  petal_length
# 0             5.1          3.5           1.4
# 1             4.9          3.0           1.4
# 2             4.7          3.2           1.3
# 3             4.6          3.1           1.5
# 4             5.0          3.6           1.4
# ..            ...          ...           ...
# 145           6.7          3.0           5.2
# 146           6.3          2.5           5.0
# 147           6.5          3.0           5.2
# 148           6.2          3.4           5.4
# 149           5.9          3.0           5.1
#
# [150 rows x 3 columns]

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
import numpy as np

pd.Series([6,np.nan, 9,None])
# Out:
# 0    6.0
# 1    NaN
# 2    9.0
# 3    NaN
# dtype: float64

# %%
data= pd.Series([6,np.nan, 'macleen',None])
data
# Out:
# 0          6
# 1        NaN
# 2    macleen
# 3       None
# dtype: object

# %%
data.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
data.notnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
data[data.notnull()]
# Out:
# 0          6
# 2    macleen
# dtype: object

# %%
data
# Out:
# 0          6
# 1        NaN
# 2    macleen
# 3       None
# dtype: object

# %%
data.dropna()
# Out:
# 0          6
# 2    macleen
# dtype: object

# %%
data
# Out:
# 0          6
# 1        NaN
# 2    macleen
# 3       None
# dtype: object

# %%
pd.DataFrame([[6,np.nan, 9], [7,2,4], [np.nan,4,1]])
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.dropna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.dropna(axis= 'columns')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df= pd.DataFrame([[6, np.nan, 9, np.nan],[7,2,4, np.nan],[np.nan, 4,1, np.nan]])
df
# Out:
#      0    1  2   3
# 0  6.0  NaN  9 NaN
# 1  7.0  2.0  4 NaN
# 2  NaN  4.0  1 NaN

# %%
df.dropna(axis='columns', how='all')
# Out:
#      0    1  2
# 0  6.0  NaN  9
# 1  7.0  2.0  4
# 2  NaN  4.0  1

# %%
data= pd.Series([6, np.nan, 9, None, 2],)
data
# Out:
# 0    6.0
# 1    NaN
# 2    9.0
# 3    NaN
# 4    2.0
# dtype: float64

# %%
data.fillna(0)
# Out:
# 0    6.0
# 1    0.0
# 2    9.0
# 3    0.0
# 4    2.0
# dtype: float64

# %%
data.fillna(method='ffill')
# Out:
# 0    6.0
# 1    6.0
# 2    9.0
# 3    9.0
# 4    2.0
# dtype: float64

# %%
data.fillna(method='bfill')
# Out:
# 0    6.0
# 1    9.0
# 2    9.0
# 3    2.0
# 4    2.0
# dtype: float64

# %%
df
# Out:
#      0    1  2   3
# 0  6.0  NaN  9 NaN
# 1  7.0  2.0  4 NaN
# 2  NaN  4.0  1 NaN

# %%
df.fillna(method='ffill', axis=1)
# Out:
#      0    1    2    3
# 0  6.0  6.0  9.0  9.0
# 1  7.0  2.0  4.0  4.0
# 2  NaN  4.0  1.0  1.0

# %%
df.fillna(method='ffill', axis=0)
# Out:
#      0    1  2   3
# 0  6.0  NaN  9 NaN
# 1  7.0  2.0  4 NaN
# 2  7.0  4.0  1 NaN

# %%
data= ['lisa','kim','DAVID','stePHEN']
[s.capitalize() for s in data]
# Out:
# ['Lisa', 'Kim', 'David', 'Stephen']

# %%
import pandas as pd
names= pd.Series(data)
names
# Out:
# 0       lisa
# 1        kim
# 2      DAVID
# 3    stePHEN
# dtype: object

# %%
names.str.capitalize()
# Out:
# 0       Lisa
# 1        Kim
# 2      David
# 3    Stephen
# dtype: object

# %%
monte= pd.Series(['lisa','kim','DAVID','stePHEN'])

# %%
monte.str.lower()
# Out:
# 0       lisa
# 1        kim
# 2      david
# 3    stephen
# dtype: object

# %%
monte.str.len
# Out:
# <bound method StringMethods.len of <pandas.core.strings.accessor.StringMethods object at 0x0000026CC6147580>>

# %%
monte.str.startswith('D')
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
monte.str.split()
# Out:
# 0       [lisa]
# 1        [kim]
# 2      [DAVID]
# 3    [stePHEN]
# dtype: object

# %%
ser1= pd.Series(['H','P','V'], index=['1','2','3'])
ser2= pd.Series(['S','D','L'], index=['4','5','6'])
pd.concat([ser1,ser2], axis=0)
# Out:
# 1    H
# 2    P
# 3    V
# 4    S
# 5    D
# 6    L
# dtype: object

# %%
pd.concat([ser1,ser2], axis=1)
# Out:
#      0    1
# 1    H  NaN
# 2    P  NaN
# 3    V  NaN
# 4  NaN    S
# 5  NaN    D
# 6  NaN    L

# %%
from IPython.display import display, HTML
display(pd.concat([ser1,ser2], axis=1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15000\2500679023.py in <module>
#       1 from IPython.display import display, HTML
# ----> 2 display(pd.concat([ser1,ser2], axis=1))
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df= pd.read_csv("movies.csv")

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
temp_df= df.append(df)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15000\2125979207.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_df= df.append(df)

# %%
temp_df.shape
# Out:
# (2000, 16)

# %%
df.shape
# Out:
# (1000, 16)

# %% [markdown]
# Handle dupicates

# %%
temp_df =temp_df.drop_duplicates()
temp_df.shape
# Out:
# (1000, 16)

# %%
temp_df.shape
# Out:
# (1000, 16)

# %% [markdown]
# Clean up columns

# %%
df.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
df.rename(columns= {"Series_Title":"movie"}, inplace=True)
df.columns
# Out:
# Index(['Poster_Link', 'movie', 'Released_Year', 'Certificate', 'Runtime',
#        'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'Star1',
#        'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
df.columns=[col.upper() for col in df]

# %%
df.columns
# Out:
# Index(['POSTER_LINK', 'MOVIE', 'RELEASED_YEAR', 'CERTIFICATE', 'RUNTIME',
#        'GENRE', 'IMDB_RATING', 'OVERVIEW', 'META_SCORE', 'DIRECTOR', 'STAR1',
#        'STAR2', 'STAR3', 'STAR4', 'NO_OF_VOTES', 'GROSS'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   POSTER_LINK    1000 non-null   object
#  1   MOVIE          1000 non-null   object
#  2   RELEASED_YEAR  1000 non-null   object
#  3   CERTIFICATE    899 non-null    object
#  4   RUNTIME        1000 non-null   object
#  5   GENRE          1000 non-null   object
#  6   IMDB_RATING    1000 non-null   float64
#  7   OVERVIEW       1000 non-null   object
#  8   META_SCORE     843 non-null    float64
#  9   DIRECTOR       1000 non-null   object
#  10  STAR1          1000 non-null   object
#  11  STAR2          1000 non-null   object
#  12  STAR3          1000 non-null   object
#  13  STAR4          1000 non-null   object
#  14  NO_OF_VOTES    1000 non-null   int64
#  15  GROSS          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %% [markdown]
# Handling missing values

# %%
df.isnull()
# Out:
#      POSTER_LINK  MOVIE  RELEASED_YEAR  CERTIFICATE  RUNTIME  GENRE  \
# 0          False  False          False        False    False  False
# 1          False  False          False        False    False  False
# 2          False  False          False        False    False  False
# 3          False  False          False        False    False  False
# 4          False  False          False        False    False  False
# ..           ...    ...            ...          ...      ...    ...
# 995        False  False          False        False    False  False
# 996        False  False          False        False    False  False
# 997        False  False          False        False    False  False
# 998        False  False          False         True    False  False
# 999        False  False          False         True    False  False
#
#      IMDB_RATING  OVERVIEW  META_SCORE  DIRECTOR  STAR1  STAR2  STAR3  STAR4  \
# ...

# %%
df.isnull().sum()
# Out:
# POSTER_LINK        0
# MOVIE              0
# RELEASED_YEAR      0
# CERTIFICATE      101
# RUNTIME            0
# GENRE              0
# IMDB_RATING        0
# OVERVIEW           0
# META_SCORE       157
# DIRECTOR           0
# STAR1              0
# STAR2              0
# STAR3              0
# STAR4              0
# NO_OF_VOTES        0
# GROSS            169
# dtype: int64

# %%
clean_df = df.dropna()

# %%
clean_df.isnull().sum()
# Out:
# POSTER_LINK      0
# MOVIE            0
# RELEASED_YEAR    0
# CERTIFICATE      0
# RUNTIME          0
# GENRE            0
# IMDB_RATING      0
# OVERVIEW         0
# META_SCORE       0
# DIRECTOR         0
# STAR1            0
# STAR2            0
# STAR3            0
# STAR4            0
# NO_OF_VOTES      0
# GROSS            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# POSTER_LINK        0
# MOVIE              0
# RELEASED_YEAR      0
# CERTIFICATE      101
# RUNTIME            0
# GENRE              0
# IMDB_RATING        0
# OVERVIEW           0
# META_SCORE       157
# DIRECTOR           0
# STAR1              0
# STAR2              0
# STAR3              0
# STAR4              0
# NO_OF_VOTES        0
# GROSS            169
# dtype: int64

# %%
columns_df = df.dropna(axis=1)
columns_df.columns
# Out:
# Index(['POSTER_LINK', 'MOVIE', 'RELEASED_YEAR', 'RUNTIME', 'GENRE',
#        'IMDB_RATING', 'OVERVIEW', 'DIRECTOR', 'STAR1', 'STAR2', 'STAR3',
#        'STAR4', 'NO_OF_VOTES'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# POSTER_LINK        0
# MOVIE              0
# RELEASED_YEAR      0
# CERTIFICATE      101
# RUNTIME            0
# GENRE              0
# IMDB_RATING        0
# OVERVIEW           0
# META_SCORE       157
# DIRECTOR           0
# STAR1              0
# STAR2              0
# STAR3              0
# STAR4              0
# NO_OF_VOTES        0
# GROSS            169
# dtype: int64

# %%
df.fillna("movie")
# Out:
#                                            POSTER_LINK  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                         MOVIE RELEASED_YEAR CERTIFICATE  RUNTIME  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
df.describe()
# Out:
#        IMDB_RATING  META_SCORE   NO_OF_VOTES
# count  1000.000000  843.000000  1.000000e+03
# mean      7.949300   77.971530  2.736929e+05
# std       0.275491   12.376099  3.273727e+05
# min       7.600000   28.000000  2.508800e+04
# 25%       7.700000   70.000000  5.552625e+04
# 50%       7.900000   79.000000  1.385485e+05
# 75%       8.100000   87.000000  3.741612e+05
# max       9.300000  100.000000  2.343110e+06

# %%
df.corr()
# Out:
#              IMDB_Rating  Meta_score  No_of_Votes
# IMDB_Rating     1.000000    0.268531     0.494979
# Meta_score      0.268531    1.000000    -0.018507
# No_of_Votes     0.494979   -0.018507     1.000000

# %%
df.loc("movie_csv")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     549         try:
# --> 550             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551         except KeyError:
#
# KeyError: 'movie_csv'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15000\1413380290.py in <module>
# ----> 1 df.loc("movie_csv")
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     632
#     633         if axis is not None:
# --> 634             axis = self.obj._get_axis_number(axis)
#     635         new_self.axis = axis
#     636         return new_self
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
# ...

# %%
df.fillna(method='ffill')
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
df.fillna(method='bfill')
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
df.loc()

# %%
df.iloc()
